# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import Flatten
from keras. layers import MaxPooling2D
from keras.layers import Dense
import numpy as np
from keras.layers import Dropout

# %%
model=Sequential()
model.add(Conv2D(60,(1,1),input_shape=(64,64,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(50,(3,3),input_shape=(64,64,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(5,5)))
model.add(Flatten())
model.add(Dense(units=256,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=128,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=4,activation='softmax'))
# Out:
# C:\Users\vikas\AppData\Roaming\Python\Python39\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 64, 64, 60)          │             240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 32, 32, 60)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 30, 30, 50)          │          27,050 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 6, 6, 50)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 1800)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         461,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 4)                   │             516 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 521,758 (1.99 MB)
#  Trainable params: 521,758 (1.99 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,              # Shearing
    zoom_range=0.4,               # Zooming
    horizontal_flip=True,         # Horizontal flipping
    rotation_range=40,            # Random rotations
    width_shift_range=0.2,        # Random width shifts
    height_shift_range=0.2,       # Random height shifts
    brightness_range=[0.8, 1.2],  # Random brightness adjustments
    channel_shift_range=0.2,      # Random channel shifts
    fill_mode='nearest'           # Filling in newly created pixels
)

test_datagen = ImageDataGenerator(rescale=1./255)

training_set = train_datagen.flow_from_directory(
    "E:/Derma_GAN/skin_leison_dataset_without_gan",
    target_size=(64, 64),
    batch_size=30,
    class_mode='sparse'
)

test_set = test_datagen.flow_from_directory(
    "E:/Derma_GAN/testing_data",
    target_size=(64, 64),
    batch_size=10,
    class_mode='sparse'
)
# Out:
# Found 1576 images belonging to 4 classes.
# Found 400 images belonging to 4 classes.

# %%
# Verify train generator
for data_batch, labels_batch in training_set:
    print("Data batch shape:", data_batch.shape)
    print("Labels batch shape:", labels_batch.shape)
    break

# Verify test generator
for data_batch, labels_batch in test_set:
    print("Data batch shape:", data_batch.shape)
    print("Labels batch shape:", labels_batch.shape)
    break
# Out:
# Data batch shape: (30, 64, 64, 3)
# Labels batch shape: (30,)
# Data batch shape: (10, 64, 64, 3)
# Labels batch shape: (10,)

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history=model.fit(training_set,steps_per_epoch =40,epochs =100)
# Out:
# Epoch 1/100
# C:\Users\vikas\AppData\Roaming\Python\Python39\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 42s 883ms/step - accuracy: 0.2932 - loss: 1.3940
# Epoch 2/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.3598 - loss: 1.3132
# Epoch 3/100
# C:\ProgramData\Anaconda3\lib\contextlib.py:137: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 19s 397ms/step - accuracy: 0.3984 - loss: 1.2746
# Epoch 4/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.4557 - loss: 1.1849
# Epoch 5/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 339ms/step - accuracy: 0.4458 - loss: 1.1710
# Epoch 6/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.4606 - loss: 1.1850
# Epoch 7/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 348ms/step - accuracy: 0.4705 - loss: 1.1512
# Epoch 8/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.4680 - loss: 1.1594
# Epoch 9/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 328ms/step - accuracy: 0.4673 - loss: 1.1425
# Epoch 10/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.5054 - loss: 1.1502
# Epoch 11/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 349ms/step - accuracy: 0.5194 - loss: 1.1041
# Epoch 12/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 0.4482 - loss: 1.1874
# Epoch 13/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 345ms/step - accuracy: 0.4790 - loss: 1.1342
# Epoch 14/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.5200 - loss: 1.0916
# Epoch 15/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 22s 491ms/step - accuracy: 0.5160 - loss: 1.0791
# Epoch 16/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 136ms/step - accuracy: 0.5024 - loss: 1.0911
# Epoch 17/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 44s 923ms/step - accuracy: 0.5299 - loss: 1.0803
# Epoch 18/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.5278 - loss: 1.0866
# Epoch 19/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 17s 373ms/step - accuracy: 0.5198 - loss: 1.0472
# Epoch 20/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.4930 - loss: 1.0991
# Epoch 21/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 341ms/step - accuracy: 0.4973 - loss: 1.0999
# Epoch 22/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.5016 - loss: 1.1222
# Epoch 23/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 326ms/step - accuracy: 0.4797 - loss: 1.1025
# Epoch 24/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.5035 - loss: 1.0235
# Epoch 25/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 326ms/step - accuracy: 0.5337 - loss: 1.0482
# Epoch 26/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.4803 - loss: 1.1335
# Epoch 27/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 329ms/step - accuracy: 0.5190 - loss: 1.0822
# Epoch 28/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.5245 - loss: 1.0703
# Epoch 29/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 326ms/step - accuracy: 0.5162 - loss: 1.0551
# Epoch 30/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.6013 - loss: 0.9722
# Epoch 31/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 327ms/step - accuracy: 0.5811 - loss: 0.9988
# Epoch 32/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.5496 - loss: 1.0384
# Epoch 33/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 330ms/step - accuracy: 0.5862 - loss: 0.9831
# Epoch 34/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.5579 - loss: 1.0153
# Epoch 35/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 327ms/step - accuracy: 0.5918 - loss: 0.9996
# Epoch 36/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.6035 - loss: 0.9553
# Epoch 37/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 325ms/step - accuracy: 0.5841 - loss: 0.9672
# Epoch 38/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.5611 - loss: 0.9746
# Epoch 39/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 328ms/step - accuracy: 0.5667 - loss: 1.0089
# Epoch 40/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.5732 - loss: 0.9823
# Epoch 41/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 331ms/step - accuracy: 0.5974 - loss: 0.9497
# Epoch 42/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.5516 - loss: 1.0111
# Epoch 43/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 332ms/step - accuracy: 0.6047 - loss: 0.9401
# Epoch 44/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.5870 - loss: 1.0080
# Epoch 45/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 335ms/step - accuracy: 0.5691 - loss: 1.0194
# Epoch 46/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.5468 - loss: 1.0246
# Epoch 47/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 333ms/step - accuracy: 0.6081 - loss: 0.9304
# Epoch 48/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.6060 - loss: 0.9152
# Epoch 49/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 327ms/step - accuracy: 0.6137 - loss: 0.9422
# Epoch 50/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.5484 - loss: 1.0066
# Epoch 51/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 325ms/step - accuracy: 0.5887 - loss: 0.9722
# Epoch 52/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.6372 - loss: 0.9491
# Epoch 53/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 330ms/step - accuracy: 0.6194 - loss: 0.9109
# Epoch 54/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.6557 - loss: 0.8750
# Epoch 55/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 331ms/step - accuracy: 0.5974 - loss: 0.9345
# Epoch 56/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.6505 - loss: 0.9316
# Epoch 57/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 329ms/step - accuracy: 0.5919 - loss: 0.9255
# Epoch 58/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.5924 - loss: 0.9635
# Epoch 59/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 326ms/step - accuracy: 0.6349 - loss: 0.8743
# Epoch 60/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.6108 - loss: 0.9508
# Epoch 61/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 347ms/step - accuracy: 0.6358 - loss: 0.9130
# Epoch 62/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.6388 - loss: 0.8614
# Epoch 63/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 329ms/step - accuracy: 0.6176 - loss: 0.8984
# Epoch 64/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.6068 - loss: 0.9685
# Epoch 65/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 331ms/step - accuracy: 0.6369 - loss: 0.8690
# Epoch 66/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.6189 - loss: 0.9359
# Epoch 67/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 334ms/step - accuracy: 0.6632 - loss: 0.8567
# Epoch 68/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.6250 - loss: 0.8833
# Epoch 69/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 327ms/step - accuracy: 0.6420 - loss: 0.8944
# Epoch 70/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - accuracy: 0.6526 - loss: 0.8609
# Epoch 71/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 326ms/step - accuracy: 0.5893 - loss: 0.9409
# Epoch 72/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.6544 - loss: 0.8320
# Epoch 73/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 326ms/step - accuracy: 0.6214 - loss: 0.8881
# Epoch 74/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.5919 - loss: 0.9421
# Epoch 75/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 339ms/step - accuracy: 0.6275 - loss: 0.8973
# Epoch 76/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.6157 - loss: 0.9072
# Epoch 77/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 333ms/step - accuracy: 0.6428 - loss: 0.8913
# Epoch 78/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - accuracy: 0.6031 - loss: 0.9114
# Epoch 79/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 329ms/step - accuracy: 0.6368 - loss: 0.8733
# Epoch 80/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.6518 - loss: 0.8807
# Epoch 81/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 338ms/step - accuracy: 0.6375 - loss: 0.8401
# Epoch 82/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.6745 - loss: 0.8573
# Epoch 83/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 332ms/step - accuracy: 0.6450 - loss: 0.8619
# Epoch 84/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.6539 - loss: 0.8423
# Epoch 85/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 333ms/step - accuracy: 0.6402 - loss: 0.8901
# Epoch 86/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.7064 - loss: 0.8052
# Epoch 87/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 327ms/step - accuracy: 0.6595 - loss: 0.7913
# Epoch 88/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.6083 - loss: 0.9247
# Epoch 89/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 333ms/step - accuracy: 0.6204 - loss: 0.8962
# Epoch 90/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.6755 - loss: 0.8579
# Epoch 91/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 331ms/step - accuracy: 0.6767 - loss: 0.7779
# Epoch 92/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.6022 - loss: 0.8932
# Epoch 93/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 332ms/step - accuracy: 0.6353 - loss: 0.8844
# Epoch 94/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.6159 - loss: 0.8779
# Epoch 95/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 328ms/step - accuracy: 0.6753 - loss: 0.8150
# Epoch 96/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.6077 - loss: 0.9118
# Epoch 97/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 326ms/step - accuracy: 0.6641 - loss: 0.8127
# Epoch 98/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.6488 - loss: 0.8170
# Epoch 99/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 15s 330ms/step - accuracy: 0.6622 - loss: 0.8421
# Epoch 100/100
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.6735 - loss: 0.7909

# %%
test_loss, test_accuracy = model.evaluate(test_set )
print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 13s 336ms/step - accuracy: 0.6777 - loss: 0.7639
# Test Loss: 0.8166099786758423
# Test Accuracy: 0.6549999713897705
